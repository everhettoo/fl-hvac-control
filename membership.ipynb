# %%
import sys
import os
from importlib import reload


from membership_functions import inc

# reload(membership_functions)
x = inc(5, 10, 15)
x
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[24], line 7
#       2 import os
#       3 from importlib import reload
# ----> 7 from membership_functions import inc
#       9 # reload(membership_functions)
#      10 x = inc(5, 10, 15)
#
# ImportError: cannot import name 'inc' from 'membership_functions' (/Users/everhett/Projects/python-ws/fl-hvac-control/membership_functions.py)
