# %% [markdown]
# # Mamdani - HVAC Control System
#
# This notebook demonstrates the complete rule testing of a Mamdani fuzzy inference system designed for HVAC control.
# Tests is devided into:
# - Optimized Rules Tests
# - Positive Tests - for Overlapping Regions
# - Negative Tests - for Exceptions

# %%
# Imports necessary modules/packages and sets up the environment for experimentation.
import sys
import os

from importlib import reload

# Navigate up to the project root directory dynamically.
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Add the project root to the system path to import custom modules from mylibs package.
sys.path.append(project_root)

# Import the custom module from the mylibs package.
import main as app

# %% [markdown]
# ## Optimized Rules Tests

# %%
# Test Rule 1: Comfortable Temp + Normal Humid + Low CO₂
reload(app)
app.hvac_control_app(23.5, 55, 450)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 23.5 °C
# Input Humidity: 55.0
# Input CO₂: 450.0 ppm
# Temperature Category: Comfortable (μ=1.00)
# Humidity Category: Normal (μ=0.80)
# CO₂ Category: Low (μ=1.00)
# HVAC Category: Off (μ=0.80)
# Input Summary:
#  - Temperature: 23.5 °C (Comfortable)
#  - Humidity: 55.0 % (Normal)
#  - CO₂: 450.0 ppm (Low)
# Recommended HVAC Level: 5.81 % (Off)

# %%
# Test Rule 2: Comfortable Temp + Normal Humid + Medium CO₂
reload(app)
app.hvac_control_app(23.5, 55, 900)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 23.5 °C
# Input Humidity: 55.0
# Input CO₂: 900.0 ppm
# Temperature Category: Comfortable (μ=1.00)
# Humidity Category: Normal (μ=0.80)
# CO₂ Category: Medium (μ=0.67)
# HVAC Category: Low (μ=0.67)
# Input Summary:
#  - Temperature: 23.5 °C (Comfortable)
#  - Humidity: 55.0 % (Normal)
#  - CO₂: 900.0 ppm (Medium)
# Recommended HVAC Level: 25.00 % (Low)

# %%
# Test Rule 3: Cold Temp + Normal Humid
reload(app)
app.hvac_control_app(20, 55, 700)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 20.0 °C
# Input Humidity: 55.0
# Input CO₂: 700.0 ppm
# Temperature Category: Cold (μ=1.00)
# Humidity Category: Normal (μ=0.80)
# CO₂ Category: Medium (μ=0.67)
# HVAC Category: Low (μ=0.80)
# Input Summary:
#  - Temperature: 20.0 °C (Cold)
#  - Humidity: 55.0 % (Normal)
#  - CO₂: 700.0 ppm (Medium)
# Recommended HVAC Level: 25.00 % (Low)

# %%
# Test Rule 4: Warm Temp + Normal Humid
reload(app)
app.hvac_control_app(28, 55, 700)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 28.0 °C
# Input Humidity: 55.0
# Input CO₂: 700.0 ppm
# Temperature Category: Warm (μ=1.00)
# Humidity Category: Normal (μ=0.80)
# CO₂ Category: Medium (μ=0.67)
# HVAC Category: Medium (μ=0.80)
# Input Summary:
#  - Temperature: 28.0 °C (Warm)
#  - Humidity: 55.0 % (Normal)
#  - CO₂: 700.0 ppm (Medium)
# Recommended HVAC Level: 55.00 % (Medium)

# %%
# Test Rule 5: High Humid
reload(app)
app.hvac_control_app(24, 75, 700)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 24.0 °C
# Input Humidity: 75.0
# Input CO₂: 700.0 ppm
# Temperature Category: Comfortable (μ=0.86)
# Humidity Category: High (μ=1.00)
# CO₂ Category: Medium (μ=0.67)
# HVAC Category: Medium (μ=0.99)
# Input Summary:
#  - Temperature: 24.0 °C (Comfortable)
#  - Humidity: 75.0 % (High)
#  - CO₂: 700.0 ppm (Medium)
# Recommended HVAC Level: 55.00 % (Medium)

# %%
# Test Rule 6: High CO₂
reload(app)
app.hvac_control_app(24, 55, 1400)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 24.0 °C
# Input Humidity: 55.0
# Input CO₂: 1400.0 ppm
# Temperature Category: Comfortable (μ=0.86)
# Humidity Category: Normal (μ=0.80)
# CO₂ Category: High (μ=1.00)
# HVAC Category: High (μ=1.00)
# Input Summary:
#  - Temperature: 24.0 °C (Comfortable)
#  - Humidity: 55.0 % (Normal)
#  - CO₂: 1400.0 ppm (High)
# Recommended HVAC Level: 88.40 % (High)

# %%
# Test Rule 7: Warm Temp + High Humid + High CO₂
reload(app)
app.hvac_control_app(28, 75, 1400)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 28.0 °C
# Input Humidity: 75.0
# Input CO₂: 1400.0 ppm
# Temperature Category: Warm (μ=1.00)
# Humidity Category: High (μ=1.00)
# CO₂ Category: High (μ=1.00)
# HVAC Category: High (μ=1.00)
# Input Summary:
#  - Temperature: 28.0 °C (Warm)
#  - Humidity: 75.0 % (High)
#  - CO₂: 1400.0 ppm (High)
# Recommended HVAC Level: 72.73 % (High)

# %% [markdown]
# ## Positive Tests - for Overlapping Regions

# %%
# When input spread across
reload(app)

app.hvac_control_app(21, 63, 1000)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 21.0 °C
# Input Humidity: 63.0
# Input CO₂: 1000.0 ppm
# Temperature Category: Cold (μ=0.50)
# Humidity Category: High (μ=0.30)
# CO₂ Category: Medium (μ=0.33)
# HVAC Category: Medium (μ=0.30)
# Input Summary:
#  - Temperature: 21.0 °C (Cold)
#  - Humidity: 63.0 % (High)
#  - CO₂: 1000.0 ppm (Medium)
# Recommended HVAC Level: 46.15 % (Medium)

# %%
# When Input Spread and is Weighted Towards the Comfort zone
reload(app)

app.hvac_control_app(21, 41.5, 550)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 21.0 °C
# Input Humidity: 41.5
# Input CO₂: 550.0 ppm
# Temperature Category: Cold (μ=0.50)
# Humidity Category: Dry (μ=0.44)
# CO₂ Category: Low (μ=0.50)
# HVAC Category: Off (μ=0.12)
# Input Summary:
#  - Temperature: 21.0 °C (Cold)
#  - Humidity: 41.5 % (Dry)
#  - CO₂: 550.0 ppm (Low)
# Recommended HVAC Level: 19.62 % (Off)

# %%
# When Inputs Spread Across the Extreme Zones
reload(app)

app.hvac_control_app(26, 62, 1050)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 26.0 °C
# Input Humidity: 62.0
# Input CO₂: 1050.0 ppm
# Temperature Category: Warm (μ=0.50)
# Humidity Category: Normal (μ=0.24)
# CO₂ Category: High (μ=0.20)
# HVAC Category: Medium (μ=0.24)
# Input Summary:
#  - Temperature: 26.0 °C (Warm)
#  - Humidity: 62.0 % (Normal)
#  - CO₂: 1050.0 ppm (High)
# Recommended HVAC Level: 57.15 % (Medium)

# %% [markdown]
# ## Negative Tests - Exceptions

# %%
# When No rule-firing strength or conflict
reload(app)

app.hvac_control_app(19, 35, 1000)
# Out:
# HVAC Control System using Fuzzy Logic
# Input Temperature: 19.0 °C
# Input Humidity: 35.0
# Input CO₂: 1000.0 ppm
# Temperature Category: Cold (μ=1.00)
# Humidity Category: Dry (μ=1.00)
# CO₂ Category: Medium (μ=0.33)
# HVAC Category: Off (μ=0.00)
# Input Summary:
#  - Temperature: 19.0 °C (Cold)
#  - Humidity: 35.0 % (Dry)
#  - CO₂: 1000.0 ppm (Medium)
# Recommended HVAC Level: 0.00 % (Off)
