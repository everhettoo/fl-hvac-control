# %% [markdown]
# # Indoor Humidity Fuzzy Membership Function
# In this notebook the identified data are used for designing the fuzzy membership functions.

# %%
# Imports necessary modules/packages and sets up the environment for experimentation.
import sys
import os

# Navigate up to the project root directory dynamically.
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Add the project root to the system path to import custom modules from mylibs package.
sys.path.append(project_root)

# Import membership functions from the mylibs package.
import mylibs.membership_functions as mf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Universe of Discourse and Membership Functions

# %%
# Universe of discourse
# Define typical CO2 concentration ranges for indoor air quality analysis (in ppm).
humidity_uod = {
    "min": 30,
    "max": 80,
    "unit": "%",
    "linguistic_terms": {
        "Dry": {"range": (30, 45)},  # Dry air
        "Normal": {"range": (45, 60)},  # Normal humidity
        "Humid": {"range": (60, 80)},  # High humidity
    },
}

"""Input discretized universes"""
humidity = np.linspace(humidity_uod["min"], humidity_uod["max"], 400)

# %% [markdown]
# # Generate and Plot Increasing Membership Functions

# %%
# Generate increasing membership values
mu_inc_low = [mf.inc(x, 30, 45) for x in humidity]
mu_inc_med = [mf.inc(x, 45, 60) for x in humidity]
mu_inc_high = [mf.inc(x, 60, 80) for x in humidity]

# %%
# Plot increasing membership functions

plt.figure(figsize=(12, 6))
plt.plot(humidity, mu_inc_low, label="Dry", color="skyblue")
plt.plot(humidity, mu_inc_med, label="Normal", color="green")
plt.plot(humidity, mu_inc_high, label="Humid", color="red")
plt.title("Increasing Fuzzy Membership Functions")
plt.xlabel("Humidity")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Decreasing Membership Functions

# %%
# Generate decreasing membership values
mu_dec_low = [mf.dec(x, 30, 45) for x in humidity]
mu_dec_med = [mf.dec(x, 45, 60) for x in humidity]
mu_dec_high = [mf.dec(x, 60, 80) for x in humidity]

# %%
# Plot decreasing membership functions

plt.figure(figsize=(12, 6))
plt.plot(humidity, mu_dec_low, label="Dry", color="skyblue")
plt.plot(humidity, mu_dec_med, label="Normal", color="green")
plt.plot(humidity, mu_dec_high, label="Humid", color="red")
plt.title("Decreasing Fuzzy Membership Functions")
plt.xlabel("Humidity")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Triangular Membership Functions

# %%
# Generate triangular membership values
mu_tri_low = [mf.tri(x, 30, 37.5, 45) for x in humidity]
mu_tri_med = [mf.tri(x, 40, 52.5, 65) for x in humidity]
mu_tri_high = [mf.tri(x, 60, 70, 80) for x in humidity]

# %%
# Plot triangular membership functions

plt.figure(figsize=(12, 6))
plt.plot(humidity, mu_tri_low, label="Dry", color="skyblue")
plt.plot(humidity, mu_tri_med, label="Comfortable", color="green")
plt.plot(humidity, mu_tri_high, label="Humid", color="red")
plt.title("Triangular Fuzzy Membership Functions")
plt.xlabel("Humidity")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Trapezoidal Membership Functions

# %%
# Generate trapezoidal membership values
mu_trap_low = [mf.trap(x, 30, 30, 40, 45) for x in humidity]
mu_trap_med = [mf.trap(x, 40, 45, 60, 65) for x in humidity]
mu_trap_high = [mf.trap(x, 60, 65, 80, 80) for x in humidity]

# %%
# Plot trapezoidal membership functions

plt.figure(figsize=(12, 6))
plt.plot(humidity, mu_trap_low, label="Dry", color="skyblue")
plt.plot(humidity, mu_trap_med, label="Normal", color="green")
plt.plot(humidity, mu_trap_high, label="Humid", color="red")
plt.title("Trapezoidal Fuzzy Membership Functions")
plt.xlabel("Humidity")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Gaussion Membership Functions

# %%
# Generate gaussion membership values
mu_gauss_low = [mf.gaussian(x, 37.5, 5) for x in humidity]
mu_gauss_med = [mf.gaussian(x, 52.5, 7.5) for x in humidity]
mu_gauss_high = [mf.gaussian(x, 70, 7.5) for x in humidity]

# %%
# Plot gaussion membership functions

plt.figure(figsize=(12, 6))
plt.plot(humidity, mu_gauss_low, label="Dry", color="skyblue")
plt.plot(humidity, mu_gauss_med, label="Normal", color="green")
plt.plot(humidity, mu_gauss_high, label="Humid", color="red")
plt.title("Gaussion Fuzzy Membership Functions")
plt.xlabel("Humidity")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Sigmoid Membership Functions

# %%
# Generate sigmoid membership values
mu_sigmoid_low = [mf.sigmoid(x, 0.3, 32.5) for x in humidity]
mu_sigmoid_med = [mf.sigmoid(x, 0.25, 52.5) for x in humidity]
mu_sigmoid_high = [mf.sigmoid(x, 0.2, 70) for x in humidity]

# %%
# Plot sigmoid membership functions

plt.figure(figsize=(12, 6))
plt.plot(humidity, mu_sigmoid_low, label="Dry", color="skyblue")
plt.plot(humidity, mu_sigmoid_med, label="Normal", color="green")
plt.plot(humidity, mu_sigmoid_high, label="Humid", color="red")
plt.title("Sigmoid Fuzzy Membership Functions")
plt.xlabel("Humidity")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()
