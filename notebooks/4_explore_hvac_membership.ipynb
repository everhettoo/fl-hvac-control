# %% [markdown]
# # HVAC Level Fuzzy Membership Function
# In this notebook the identified data are used for designing the fuzzy membership functions.

# %%
# Imports necessary modules/packages and sets up the environment for experimentation.
import sys
import os

# Navigate up to the project root directory dynamically.
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Add the project root to the system path to import custom modules from mylibs package.
sys.path.append(project_root)

# Import membership functions from the mylibs package.
import mylibs.membership_functions as mf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Universe of Discourse and Linguistic Terms

# %%
# Universe of discourse
# Define typical CO2 concentration ranges for indoor air quality analysis (in ppm).
hvac_uod = {
    'min': 0,
    'max': 100,
    'unit': '%',
    'linguistic_terms': {
        'OFF': {'range': (0, 15)},      # OFF
        'LOW': {'range': (15, 40)},     # Low
        'MEDIUM': {'range': (40, 70)},  # Medium
        'HIGH': {'range': (70, 100)}    # High
    }
}

"""Input discretized universes"""
hvac = np.linspace(hvac_uod['min'], hvac_uod['max'], 400)

# %% [markdown]
# # Generate and Plot Increasing Membership Functions

# %%
# Generate increasing membership values
mu_inc_off = [mf.inc(x, 0, 15) for x in hvac]
mu_inc_low = [mf.inc(x, 15, 40) for x in hvac]
mu_inc_med = [mf.inc(x, 40, 70) for x in hvac]
mu_inc_high = [mf.inc(x, 70, 100) for x in hvac]

# %%
# Plot increasing membership functions

plt.figure(figsize=(12,6))
plt.plot(hvac, mu_inc_off, label='Off', color='skyblue')
plt.plot(hvac, mu_inc_low, label='Low', color='green')
plt.plot(hvac, mu_inc_med, label='Medium', color='orange')
plt.plot(hvac, mu_inc_high, label='High', color='red')
plt.title("Increasing Fuzzy Membership Functions")
plt.xlabel("HVAC")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Decreasing Membership Functions

# %%
# Generate decreasing membership values
mu_dec_off = [mf.dec(x, 0, 15) for x in hvac]
mu_dec_low = [mf.dec(x, 15, 40) for x in hvac]
mu_dec_med = [mf.dec(x, 40, 70) for x in hvac]
mu_dec_high = [mf.dec(x, 70, 100) for x in hvac]

# %%
# Plot decreasing membership functions

plt.figure(figsize=(12,6))
plt.plot(hvac, mu_dec_off, label='Off', color='skyblue')
plt.plot(hvac, mu_dec_low, label='Low', color='green')
plt.plot(hvac, mu_dec_med, label='Medium', color='orange')
plt.plot(hvac, mu_dec_high, label='High', color='red')
plt.title("Decreasing Fuzzy Membership Functions")
plt.xlabel("HVAC")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Triangular Membership Functions

# %%
# Generate triangular membership values
mu_tri_off = [mf.tri(x, 0, 7.5, 15) for x in hvac]
mu_tri_low = [mf.tri(x, 10, 25, 40) for x in hvac]
mu_tri_med = [mf.tri(x, 35, 55, 75) for x in hvac]
mu_tri_high = [mf.tri(x, 70, 85, 100) for x in hvac]

# %%
# Plot triangular membership functions

plt.figure(figsize=(12,6))
plt.plot(hvac, mu_tri_off, label='Off', color='skyblue')
plt.plot(hvac, mu_tri_low, label='Low', color='green')
plt.plot(hvac, mu_tri_med, label='Medium', color='orange')
plt.plot(hvac, mu_tri_high, label='High', color='red')
plt.title("Triangular Fuzzy Membership Functions")
plt.xlabel("HVAC")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Trapezoidal Membership Functions

# %%
# Generate trapezoidal membership values
mu_trap_off = [mf.trap(x, 0, 0, 5, 15) for x in hvac]
mu_trap_low = [mf.trap(x, 10, 15, 35, 40) for x in hvac]
mu_trap_med = [mf.trap(x, 35, 40, 70, 75) for x in hvac]
mu_trap_high = [mf.trap(x, 70, 85, 100, 100) for x in hvac]

# %%
# Plot trapezoidal membership functions

plt.figure(figsize=(12,6))
plt.plot(hvac, mu_trap_off, label='Off', color='skyblue')
plt.plot(hvac, mu_trap_low, label='Low', color='green')
plt.plot(hvac, mu_trap_med, label='Medium', color='orange')
plt.plot(hvac, mu_trap_high, label='High', color='red')
plt.title("Trapezoidal Fuzzy Membership Functions")
plt.xlabel("HVAC")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Gaussion Membership Functions

# %%
# Generate gaussion membership values
mu_gauss_off = [mf.gaussian(x, 5, 5) for x in hvac]
mu_gauss_low = [mf.gaussian(x, 25, 5) for x in hvac]
mu_gauss_med = [mf.gaussian(x, 55, 7.5) for x in hvac]
mu_gauss_high = [mf.gaussian(x, 85, 7.5) for x in hvac]

# %%
# Plot gaussion membership functions

plt.figure(figsize=(12,6))
plt.plot(hvac, mu_gauss_off, label='Off', color='skyblue')
plt.plot(hvac, mu_gauss_low, label='Low', color='green')
plt.plot(hvac, mu_gauss_med, label='Medium', color='orange')
plt.plot(hvac, mu_gauss_high, label='High', color='red')
plt.title("Gaussion Fuzzy Membership Functions")
plt.xlabel("HVAC")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Sigmoid Membership Functions

# %%
# Generate sigmoid membership values
mu_sigmoid_off = [mf.sigmoid(x, 0.3, 5) for x in hvac]
mu_sigmoid_low = [mf.sigmoid(x, 0.25, 25) for x in hvac]
mu_sigmoid_med = [mf.sigmoid(x, 0.2, 55) for x in hvac]
mu_sigmoid_high = [mf.sigmoid(x, 0.15, 85) for x in hvac]

# %%
# Plot sigmoid membership functions

plt.figure(figsize=(12, 6))
plt.plot(hvac, mu_sigmoid_off, label='Off', color='skyblue')
plt.plot(hvac, mu_sigmoid_low, label='Low', color='green')
plt.plot(hvac, mu_sigmoid_med, label='Medium', color='orange')
plt.plot(hvac, mu_sigmoid_high, label='High', color='red')
plt.title("Sigmoid Fuzzy Membership Functions")
plt.xlabel("HVAC")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()
