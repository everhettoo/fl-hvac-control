# %% [markdown]
# # Indoor Temperature Fuzzy Membership Function
# In this notebook the identified data are used for designing the fuzzy membership functions.

# %%
# Imports necessary modules/packages and sets up the environment for experimentation.
import sys
import os

# Navigate up to the project root directory dynamically.
project_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

# Add the project root to the system path to import custom modules from mylibs package.
sys.path.append(project_root)

# Import membership functions from the mylibs package.
import mylibs.membership_functions as mf
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Define Universe of Discourse and Membership Functions

# %%
# Universe of discourse
# Define typical CO2 concentration ranges for indoor air quality analysis (in ppm).
temp_uod = {
    "min": 18,
    "max": 30,
    "unit": "°C",
    "linguistic_terms": {
        "Cool": {"range": (18, 22)},  # Cool environment
        "Comfortable": {"range": (22, 25)},  # Comfortable zone
        "Warm": {"range": (25, 30)},  # Warm environment
    },
}

"""Input discretized universes"""
temp = np.linspace(temp_uod["min"], temp_uod["max"], 400)

# %% [markdown]
# # Generate and Plot Increasing Membership Functions

# %%
# Generate increasing membership values
mu_inc_low = [mf.inc(x, 18, 22) for x in temp]
mu_inc_med = [mf.inc(x, 22, 25) for x in temp]
mu_inc_high = [mf.inc(x, 25, 30) for x in temp]

# %%
# Plot increasing membership functions

plt.figure(figsize=(12, 6))
plt.plot(temp, mu_inc_low, label="Cool", color="skyblue")
plt.plot(temp, mu_inc_med, label="Comfortable", color="green")
plt.plot(temp, mu_inc_high, label="Warm", color="red")
plt.title("Increasing Fuzzy Membership Functions")
plt.xlabel("Temperature")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Decreasing Membership Functions

# %%
# Generate decreasing membership values
mu_dec_low = [mf.dec(x, 18, 22) for x in temp]
mu_dec_med = [mf.dec(x, 22, 25) for x in temp]
mu_dec_high = [mf.dec(x, 25, 30) for x in temp]

# %%
# Plot decreasing membership functions

plt.figure(figsize=(12, 6))
plt.plot(temp, mu_dec_low, label="Cool", color="skyblue")
plt.plot(temp, mu_dec_med, label="Comfortable", color="green")
plt.plot(temp, mu_dec_high, label="Warm", color="red")
plt.title("Decreasing Fuzzy Membership Functions")
plt.xlabel("Temperature")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Triangular Membership Functions

# %%
# Generate triangular membership values
mu_tri_low = [mf.tri(x, 18, 20, 22) for x in temp]
mu_tri_med = [mf.tri(x, 20, 23.5, 27) for x in temp]
mu_tri_high = [mf.tri(x, 25, 27.5, 30) for x in temp]

# %%
# Plot triangular membership functions

plt.figure(figsize=(12, 6))
plt.plot(temp, mu_tri_low, label="Cool", color="skyblue")
plt.plot(temp, mu_tri_med, label="Comfortable", color="green")
plt.plot(temp, mu_tri_high, label="Warm", color="red")
plt.title("Triangular Fuzzy Membership Functions")
plt.xlabel("Temperature")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Trapezoidal Membership Functions

# %%
# Generate trapezoidal membership values
mu_trap_low = [mf.trap(x, 18, 18, 20, 22) for x in temp]
mu_trap_med = [mf.trap(x, 21, 22, 25, 26) for x in temp]
mu_trap_high = [mf.trap(x, 25, 27, 30, 30) for x in temp]

# %%
# Plot trapezoidal membership functions

plt.figure(figsize=(12, 6))
plt.plot(temp, mu_trap_low, label="Cool", color="skyblue")
plt.plot(temp, mu_trap_med, label="Comfortable", color="green")
plt.plot(temp, mu_trap_high, label="Warm", color="red")
plt.title("Trapezoidal Fuzzy Membership Functions")
plt.xlabel("Temperature")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Gaussion Membership Functions

# %%
# Generate gaussion membership values
mu_gauss_low = [mf.gaussian(x, 20, 1.0) for x in temp]
mu_gauss_med = [mf.gaussian(x, 23.5, 1.5) for x in temp]
mu_gauss_high = [mf.gaussian(x, 27.5, 1.5) for x in temp]

# %%
# Plot gaussion membership functions

plt.figure(figsize=(12, 6))
plt.plot(temp, mu_gauss_low, label="Cool", color="skyblue")
plt.plot(temp, mu_gauss_med, label="Comfortable", color="green")
plt.plot(temp, mu_gauss_high, label="Warm", color="red")
plt.title("Gaussion (ramp) Fuzzy Membership Functions")
plt.xlabel("Temperature")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Generate and Plot Sigmoid Membership Functions

# %%
# Generate sigmoid membership values
mu_sigmoid_low = [mf.sigmoid(x, 2.0, 20) for x in temp]
mu_sigmoid_med = [mf.sigmoid(x, 2.0, 23.5) for x in temp]
mu_sigmoid_high = [mf.sigmoid(x, 1.5, 27.5) for x in temp]

# %%
# Plot sigmoid membership functions

plt.figure(figsize=(12, 6))
plt.plot(temp, mu_sigmoid_low, label="Cool", color="skyblue")
plt.plot(temp, mu_sigmoid_med, label="Comfortable", color="green")
plt.plot(temp, mu_sigmoid_high, label="Warm", color="red")
plt.title("Sigmoid (ramp) Fuzzy Membership Functions")
plt.xlabel("Temperature")
plt.ylabel("HVAC Membership Degree")
plt.legend()
plt.grid(True)
plt.show()
